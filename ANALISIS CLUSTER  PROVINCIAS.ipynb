# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

import pandas as pd

# Cargar el dataset usando coma como separador
data = pd.read_csv('/content/cluster.csv', sep=';')

# %%
print(data.columns)
# Out:
# Index(['REGION', 'DEPARTAMENTO', 'PROVINCIA', 'TECNO', 'CONEXIONES',
#        'PDEPARTAMENTO', 'PPROVINCIA', 'VELMEDS', 'VELMEDB'],
#       dtype='object')

# %%
# Verificar que las columnas se hayan leído correctamente
print(data.columns)

# Seleccionar las columnas relevantes para el clustering
X = data[['CONEXIONES', 'PDEPARTAMENTO', 'PPROVINCIA', 'VELMEDS', 'VELMEDB']]

# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar K-means clustering
kmeans = KMeans(n_clusters=5, random_state=42)  # Cambia n_clusters a la cantidad de clusters que desees
data['Cluster'] = kmeans.fit_predict(X_scaled)

# Visualizar los clusters
plt.figure(figsize=(12, 8))
for cluster in range(4):  # Cambia el rango a la cantidad de clusters que desees
    clustered_data = data[data['Cluster'] == cluster]
    plt.scatter(clustered_data['VELMEDS'], clustered_data['VELMEDB'], label=f'Cluster {cluster}')

# Añadir nombres de provincias a los puntos
for i in range(len(data)):
    plt.text(data['VELMEDS'][i], data['VELMEDB'][i], data['PROVINCIA'][i], fontsize=8)

plt.xlabel('Velocidad Media de Subida (VELMEDS)')
plt.ylabel('Velocidad Media de Bajada (VELMEDB)')
plt.title('Clustering de Provincias por Conexiones y Velocidad Media')
plt.legend()
plt.show()
# Out:
# Index(['REGION', 'DEPARTAMENTO', 'PROVINCIA', 'TECNO', 'CONEXIONES',
#        'PDEPARTAMENTO', 'PPROVINCIA', 'VELMEDS', 'VELMEDB', 'Cluster'],
#       dtype='object')
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap

# Cargar el dataset usando coma como separador
data = pd.read_csv('/content/cluster.csv', sep=';')


# Seleccionar las columnas relevantes para el clustering
X = data[['CONEXIONES', 'PDEPARTAMENTO', 'PPROVINCIA', 'VELMEDS', 'VELMEDB']]

# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar K-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)  # Cambia n_clusters a la cantidad de clusters que desees
data['Cluster'] = kmeans.fit_predict(X_scaled)

# Visualizar los clusters
plt.figure(figsize=(14, 10))
colors = plt.get_cmap('tab10').colors  # Paleta de colores más distinta

for cluster in range(5):  # Cambia el rango a la cantidad de clusters que desees
    clustered_data = data[data['Cluster'] == cluster]
    plt.scatter(clustered_data['VELMEDS'], clustered_data['VELMEDB'],
                color=colors[cluster], label=f'Cluster {cluster}', edgecolor='k', s=100, alpha=0.7)

# Añadir nombres de provincias a los puntos
for i in range(len(data)):
    plt.text(data['VELMEDS'][i], data['VELMEDB'][i], data['PROVINCIA'][i], fontsize=8, ha='right')

plt.xlabel('Velocidad Media de Subida (VELMEDS)')
plt.ylabel('Velocidad Media de Bajada (VELMEDB)')
plt.title('Clustering de Provincias por Conexiones y Velocidad Media')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Cargar el dataset usando coma como separador
data = pd.read_csv('/content/cluster.csv', sep=';')

# Seleccionar las columnas relevantes para el clustering
X = data[['CONEXIONES', 'PDEPARTAMENTO', 'PPROVINCIA', 'VELMEDS', 'VELMEDB']]

# Escalar los datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Aplicar PCA para reducir la dimensionalidad a 2 componentes
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Aplicar K-means clustering en los datos reducidos
kmeans = KMeans(n_clusters=4, random_state=42)  # Cambia n_clusters a la cantidad de clusters que desees
data['Cluster'] = kmeans.fit_predict(X_pca)

# Visualizar los clusters
plt.figure(figsize=(14, 10))
colors = plt.get_cmap('tab10').colors  # Paleta de colores más distinta

for cluster in range(5):  # Cambia el rango a la cantidad de clusters que desees
    clustered_data = data[data['Cluster'] == cluster]
    plt.scatter(clustered_data['VELMEDS'], clustered_data['VELMEDB'],
                color=colors[cluster], label=f'Cluster {cluster}', edgecolor='k', s=100, alpha=0.7)

# Añadir nombres de provincias a los puntos
for i in range(len(data)):
    plt.text(data['VELMEDS'][i], data['VELMEDB'][i], data['DEPARTAMENTO'][i], fontsize=8, ha='right')

plt.xlabel('Velocidad Media de Subida (VELMEDS)')
plt.ylabel('Velocidad Media de Bajada (VELMEDB)')
plt.title('Clustering de Provincias por Conexiones y Velocidad Media')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.manifold import TSNE

# Aplicar t-SNE para reducción de dimensionalidad
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Aplicar K-means clustering en los datos reducidos por t-SNE
kmeans = KMeans(n_clusters=4, random_state=42)  # Cambia n_clusters a la cantidad de clusters que desees
data['Cluster'] = kmeans.fit_predict(X_tsne)

# Visualizar los clusters con t-SNE
plt.figure(figsize=(14, 10))
colors = plt.get_cmap('tab10').colors  # Paleta de colores más distinta

for cluster in range(5):  # Cambia el rango a la cantidad de clusters que desees
    clustered_data = data[data['Cluster'] == cluster]
    plt.scatter(X_tsne[clustered_data.index, 0], X_tsne[clustered_data.index, 1],
                color=colors[cluster], label=f'Cluster {cluster}', edgecolor='k', s=100, alpha=0.7)

# Añadir nombres de provincias a los puntos
for i in range(len(data)):
    plt.text(X_tsne[i, 0], X_tsne[i, 1], data['PROVINCIA'][i], fontsize=8, ha='right')

plt.xlabel('Componente t-SNE 1')
plt.ylabel('Componente t-SNE 2')
plt.title('Clustering de Provincias con t-SNE')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ## MAPA DE CALOR - NIVEL DE PENETRACION DE INTERNET FIJO EN EL PERU
# ---

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Ruta al shapefile
shapefile_path = "/content/sample_data/SHAPE"

# Cargar el shapefile
gdf = gpd.read_file(shapefile_path)

# Verificar columnas (ya identificado)
print(gdf.columns)

# Datos proporcionados
data = {
    "Departamento": [
        "LIMA", "MOQUEGUA", "CALLAO", "TACNA", "ICA", "LAMBAYEQUE", "TUMBES",
        "AREQUIPA", "LA LIBERTAD", "ANCASH", "UCAYALI", "PIURA", "CUSCO", "JUNIN",
        "HUANUCO", "AYACUCHO", "SAN MARTIN", "MADRE DE DIOS", "APURIMAC", "PUNO",
        "CAJAMARCA", "HUANCAVELICA", "PASCO", "AMAZONAS", "LORETO"
    ],
    "Valor": [
        0.1720564292519231589, 0.1328428583825897463, 0.1294778851512266312,
        0.1290650762147110140, 0.1258257492784760368, 0.1201242858779514429,
        0.1184303576533606175, 0.1178277357160478560, 0.0912186654319461789,
        0.0814248961474469043, 0.0719022856376358140, 0.0660513279989225805,
        0.0636880927591237143, 0.0630969400712832410, 0.0562006893612721966,
        0.0559152684305389142, 0.0522642543803047087, 0.0500332191955844023,
        0.0485260164887072171, 0.0372748743977148433, 0.0362046937365407153,
        0.0303779374544079905, 0.0300729971202276571, 0.0191339167293047290,
        0.0182827305982500869
    ]
}


# Convertir los datos en un GeoDataFrame
df = gpd.GeoDataFrame(data)

# Unir el shapefile con los datos según el nombre del departamento
merged = gdf.merge(df, left_on="NOMBDEP", right_on="Departamento")

# Crear el mapa de calor
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
merged.boundary.plot(ax=ax)
merged.plot(column="Valor", ax=ax, legend=True,
            cmap="RdYlGn",  # Mapa de color de rojo (bajo) a verde (alto)
            legend_kwds={'label': "NIVEL DE COBERTURA 4G",
                         'orientation': "vertical"})
#plt.title("Mapa de Calor de Valores por Departamento en Perú", fontsize=15)
plt.axis('off')
plt.show()
# Out:
# Index(['OBJECTID', 'CCDD', 'NOMBDEP', 'FUENTE', 'FUENTE_1', 'POB_PROYEC',
#        'POBTOTAL', 'POB_EDAD_T', 'POB_EDAD_1', 'POB_EDAD_E', 'POB_EDAD_2',
#        'DENSIDAD', 'POBMASCU', 'POBFEMEN', 'POBMASCU_P', 'POBFEMEN_P',
#        'R_MASCULIN', 'POBURBANA', 'POBRURAL', 'POBURBANA_', 'POBRURAL_P',
#        'EDAD_PROME', 'EDAD_MEDIA', 'POB_0_14', 'POB_0_14_P', 'POB_15_29',
#        'POB_15_29_', 'POB_30_59', 'POB_30_59_', 'POB_60_MAS', 'POB_60_M_1',
#        'POB_ANALFA', 'POB_ANAL_1', 'HOMBRES_AN', 'HOMBRES__1', 'MUJERES_AN',
#        'MUJERES__1', 'MUJERES_ED', 'MUJERES__2', 'TOTAL_MADR', 'MADRES_SOL',
#        'MADRES_S_1', 'MUJERES_AD', 'MADRES_ADO', 'MADRES_A_1', 'AL_MENOS_1',
#        'AL_MENOS_2', 'SIN_DISCAP', 'SIN_DISC_1', 'ALGUNA_NBI', 'NBI_PORC',
#        'VIV_PARTIC', 'VIV_PART_1', 'VIV_PART_2', 'HOGARES', 'Shape_Leng',
#        'Shape_Area', 'IC_INF', 'IC_SUP', 'UBIC_POBMO', 'TOTAL_DEFU',
#        'TOTAL_DE_1', 'TOTAL_DE_2', 'NAC_BAJOPE', 'NAC_BAJO_1', 'MUJERES_NA',
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Ruta al shapefile
shapefile_path = "/content/sample_data/PROVINCIAS"

# Cargar el shapefile
gdf = gpd.read_file(shapefile_path)

# Verificar columnas (ya identificado)
print(gdf.columns)

# Datos proporcionados
data = {
    "PROVINCIA": [
        "LIMA", "CHICLAYO", "NASCA", "ILO", "TRUJILLO", "TUMBES", "SANTA", "AREQUIPA", "CUSCO", "TACNA",
        "ICA", "MARISCAL NIETO", "CALLAO", "PISCO", "TALARA", "SAN MARTIN", "HUANCAYO", "HUARAZ", "CHINCHA", "ABANCAY",
        "HUANUCO", "HUAMANGA", "CAÑETE", "CORONEL PORTILLO", "PIURA", "ZARUMILLA", "CAJAMARCA", "HUAURA", "ALTO AMAZONAS",
        "HUANCAVELICA", "ISLAY", "FERREÑAFE", "PUNO", "CHACHAPOYAS", "MOYOBAMBA", "PAITA", "HUARAL", "PACASMAYO",
        "LEONCIO PRADO", "HUAROCHIRI", "CONTRALMIRANTE VILLAR", "SAN ROMAN", "BARRANCA", "TAMBOPATA", "CHEPEN", "JAEN",
        "PASCO", "SULLANA", "TARMA", "ANDAHUAYLAS", "CAMANA", "LAMBAYEQUE", "URUBAMBA", "RIOJA", "HUAYLAS", "HUARMEY",
        "CASMA", "LA CONVENCION", "TARATA", "PARINACOCHAS", "CASTILLA", "CAYLLOMA", "CANCHIS", "CONCEPCION", "MARISCAL CACERES",
        "ASCOPE", "YAULI", "HUANTA", "CHANCHAMAYO", "CHUPACA", "EL COLLAO", "HUALLAGA", "MORROPON", "MANU", "CAJABAMBA",
        "PUTUMAYO", "BELLAVISTA", "PALPA", "CARAVELI", "LUCANAS", "YUNGUYO", "CALCA", "TOCACHE", "OXAPAMPA", "BAGUA",
        "JAUJA", "CUTERVO", "JORGE BASADRE", "PUERTO INCA", "CONDESUYOS", "PURUS", "MELGAR", "CHOTA", "CHUCUITO", "YAUYOS",
        "GRAU", "CANDARAVE", "HUALGAYOC", "CASTROVIRREYNA", "YUNGAY", "VIRU", "CAJATAMBO", "SECHURA", "JUNIN", "SATIPO",
        "SANCHEZ CARRION", "PAUCAR DEL SARA SARA", "SANDIA", "AZANGARO", "CANTA", "OCROS", "CONDORCANQUI", "ANTABAMBA",
        "CELENDIN", "ANTA", "GENERAL SANCHEZ CERRO", "RECUAY", "PICOTA", "ATALAYA", "PATAZ", "UTCUBAMBA", "PADRE ABAD",
        "HUAYTARA", "MAYNAS", "TAYACAJA", "GRAN CHIMU", "AYMARAES", "EL DORADO", "RODRIGUEZ DE MENDOZA", "SUCRE", "CARABAYA",
        "HUANCABAMBA", "AIJA", "CARHUAZ", "CORONGO", "HUANCA SANCOS", "MARISCAL RAMON CASTILLA", "ACOBAMBA", "HUARI",
        0.007282484, 0.007044395, 0.006924118, 0.006752078, 0.006535548, 0.006378582, 0.006193594, 0.006086645, 0.005984628,
        0.005968721, 0.005711639, 0.005665063, 0.005634398, 0.005582663, 0.005428461, 0.005383218, 0.005353496, 0.005309735,
        0.005256668, 0.005249386, 0.005203949, 0.005026954, 0.005005299, 0.004690212, 0.004689954, 0.004637020, 0.004549443,
        0.004373971, 0.004301808, 0.004224107, 0.003979852, 0.003857896, 0.003842177, 0.003722854, 0.003683763, 0.003682793,
        0.003615275, 0.003581071, 0.003568114, 0.003521065, 0.003320897, 0.003273504, 0.003223207, 0.003190650, 0.003143036,
        0.003011642, 0.002857520, 0.002822201, 0.002689715, 0.002600339, 0.002586804, 0.002565363, 0.002474743, 0.002387079,
        0.002059067, 0.002014099, 0.001964907, 0.001941362, 0.001737574, 0.001704879, 0.001074604
    ]
}



# Convertir los datos en un GeoDataFrame
df = gpd.GeoDataFrame(data)

# Unir el shapefile con los datos según el nombre del departamento
merged = gdf.merge(df, left_on="NOMBPROV", right_on="PROVINCIA")

# Crear el mapa de calor
fig, ax = plt.subplots(1, 1, figsize=(10, 15))
merged.boundary.plot(ax=ax)
merged.plot(column="RATIO_CONEXIONES_PROV", ax=ax, legend=True,
            cmap="RdYlGn",  # Mapa de color de rojo (bajo) a verde (alto)
            legend_kwds={'label': "NIVEL DE COBERTURA 4G",
                         'orientation': "vertical"})
#plt.title("Mapa de Calor de Valores por Departamento en Perú", fontsize=15)
plt.axis('off')
plt.show()
# Out:
# Index(['OBJECTID', 'NOMBDEP', 'IDPROV', 'CCPP', 'CCDD', 'NOMBPROV', 'FUENTE',
#        'POB_PROYEC', 'POBTOTAL', 'POB_EDAD_T', 'POB_EDAD_1', 'POB_EDAD_E',
#        'POB_EDAD_2', 'DENSIDAD', 'POBMASCU', 'POBFEMEN', 'POBMASCU_P',
#        'POBFEMEN_P', 'R_MASCULIN', 'POBURBANA', 'POBRURAL', 'POBURBANA_',
#        'POBRURAL_P', 'EDAD_PROME', 'EDAD_MEDIA', 'POB_0_14', 'POB_0_14_P',
#        'POB_15_29', 'POB_15_29_', 'POB_30_59', 'POB_30_59_', 'POB_60_MAS',
#        'POB_60_M_1', 'POB_ANALFA', 'POB_ANAL_1', 'HOMBRES_AN', 'HOMBRES__1',
#        'MUJERES_AN', 'MUJERES__1', 'MUJERES_ED', 'MUJERES__2', 'TOTAL_MADR',
#        'MADRES_SOL', 'MADRES_S_1', 'MUJERES_AD', 'MADRES_ADO', 'MADRES_A_1',
#        'AL_MENOS_1', 'AL_MENOS_2', 'SIN_DISCAP', 'SIN_DISC_1', 'ALGUNA_NBI',
#        'NBI_PORC', 'VIV_PARTIC', 'VIV_PART_1', 'VIV_PART_2', 'HOGARES',
#        'IC_INF', 'IC_SUP', 'UBIC_POBMO', 'TOTAL_DEFU', 'TOTAL_DE_1',
#        'TOTAL_DE_2', 'NAC_BAJOPE', 'NAC_BAJO_1', 'MUJERES_NA', 'MUJERES__3',
# ...
